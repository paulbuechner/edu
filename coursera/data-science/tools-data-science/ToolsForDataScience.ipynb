# %% [markdown]
# # My Jupyter Notebook in VSCode because I wasn't able to make an account on IBM Watson Studio

# %% [markdown]
# **Paul**
#
# Desired occupation: Data Scientist

# %% [markdown]
# I am interested in data science because i want to make an impact by discovering hidden correlations in various subjects.

# %% [markdown]
# ### Program to display the Fibonacci sequence up to n-th term

# %%
nterms = int(input("How many terms? "))

# first two terms
n1, n2 = 0, 1
count = 0

# check if the number of terms is valid
if nterms <= 0:
   print("Please enter a positive integer")
elif nterms == 1:
   print("Fibonacci sequence upto",nterms,":")
   print(n1)
else:
   print("Fibonacci sequence:")
   while count < nterms:
       print(n1)
       nth = n1 + n2
       # update values
       n1 = n2
       n2 = nth
       count += 1
# Out:
# Fibonacci sequence:
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %% [markdown]
# - this is a bullet point
# 1. this is numbered point
#
# Free Bitcoins [here](https://www.youtube.com/watch?v=dQw4w9WgXcQ).
